# %%
import pandas as pd
import re
from pandas import ExcelWriter

# %%
xl_file = pd.ExcelFile('Prueba Tableau.xlsx')

dfs = {sheet_name: xl_file.parse(sheet_name) 
          for sheet_name in xl_file.sheet_names}

# %%
df = pd.read_excel(open('Prueba Tableau.xlsx', 'rb'),
              sheet_name='Monthly Sales')

# %%
df.head()
# Out:
#     Unnamed: 0       Unnamed: 1 Unnamed: 2   2017  2017.1  2017.2  2017.3  \
# 0          NaN              NaN        NaN      1       2       3       4
# 1          NaN              NaN        NaN    218     152     191     223
# 2         Item   Metodo de Pago      Total  12017   22017   32017   42017
# 3  AUTO 1715 -   Financiamiento          1      1       0       0       0
# 4  AUTO 3492 -  Pago de contado          1      0       0       0       1
#
#    2017.4           Unnamed: 8
# 0       5                  NaN
# 1     245                  NaN
# 2   52017       Fecha de Venta
# 3       0  2017-01-22 00:00:00
# 4       0  2017-04-18 00:00:00

# %%
df = df.rename(columns={"Unnamed: 0": "Item", "Unnamed: 1": "Metodo de Pago",'Unnamed: 2':'Total',
                   "2017": "2017-1", "2017.1": "2017-2",'2017.2':'2017-3',
                   "2017.3": "2017-4", "2017.4": "2017-5",'Unnamed: 8':'Fecha de Venta'})

# %%
df = df.iloc[3:]

# %%
df = df.reset_index(drop=True)

# %%
df.Item
# Out:
# 0       AUTO 1715 -
# 1       AUTO 3492 -
# 2       AUTO 3614 -
# 3       AUTO 3002 -
# 4       AUTO 2321 -
#            ...
# 1024    AUTO 4091 -
# 1025    AUTO 3441 -
# 1026    AUTO 3697 -
# 1027    AUTO 3522 -
# 1028    AUTO 4127 -
# Name: Item, Length: 1029, dtype: object

# %%
df[['auto','Id','x']] = df.Item.str.split(" ",expand=True)

# %%
df.drop(['auto', 'x'], axis=1,inplace=True)

# %%
df.head()
# Out:
#           Item   Metodo de Pago Total  2017  2017-2  2017-3  2017-4  2017-5  \
# 0  AUTO 1715 -   Financiamiento     1     1       0       0       0       0
# 1  AUTO 3492 -  Pago de contado     1     0       0       0       1       0
# 2  AUTO 3614 -   Financiamiento     1     0       0       1       0       0
# 3  AUTO 3002 -  Pago de contado     1     0       0       0       0       1
# 4  AUTO 2321 -  Pago de contado     1     1       0       0       0       0
#
#         Fecha de Venta    Id
# 0  2017-01-22 00:00:00  1715
# 1  2017-04-18 00:00:00  3492
# 2  2017-03-28 00:00:00  3614
# 3  2017-05-03 00:00:00  3002
# 4  2017-01-12 00:00:00  2321

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Item            1029 non-null   object
#  1   Metodo de Pago  1029 non-null   object
#  2   Total           1029 non-null   object
#  3   2017            1029 non-null   int64
#  4   2017-2          1029 non-null   int64
#  5   2017-3          1029 non-null   int64
#  6   2017-4          1029 non-null   int64
#  7   2017-5          1029 non-null   int64
#  8   Fecha de Venta  1029 non-null   object
#  9   Id              1029 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 80.5+ KB

# %%
def save_xls(dict_df, path):

    writer = ExcelWriter(path)
    for key in dict_df:
        dict_df[key].to_excel(writer, key)

    writer.save()

# %%
df2 = pd.read_excel(open('Prueba Tableau.xlsx', 'rb'),
              sheet_name='Purchases',names=['Stock ID & Marca', 'Precio de Venta Con IVA', '# autos',
                                                       'Tipo de oferta','Fecha de compra','Location Compra',
                                                        'Precio de compra SIN IVA','IVA Precio de Compra',
                                                        'Precio de compra con IVA'])

# %%
df2
# Out:
#        Stock ID & Marca  Precio de Venta Con IVA  # autos  Tipo de oferta  \
# 0      Stock ID & Marca  Precio de Venta Con IVA  # autos  Tipo de oferta
# 1              3453Seat                   131638        1       Inmediata
# 2        3452Volkswagen                   193317        1       Inmediata
# 3              3448Ford                   201046        1       Inmediata
# 4              3457Mini                   201261        1       Inmediata
# ...                 ...                      ...      ...             ...
# 1096  3899Mercedes Benz                   551861        1  A consignación
# 1097      4023Chevrolet                   301545        1  A consignación
# 1098      4320Chevrolet                   922229        1  A consignación
# 1099     4474Land Rover                   695600        1  A consignación
# 1100     4508Volkswagen                   334443        1  A consignación
#
#           Fecha de compra  Location Compra  Precio de compra SIN IVA  \
# 0         Fecha de compra  Location Compra  Precio de compra SIN IVA
# 1     2017-01-02 00:00:00        FLORENCIA                    114468
# 2     2017-01-02 00:00:00        FLORENCIA                    168102
# 3     2017-01-02 00:00:00     CASA CLIENTE                    174823
# 4     2017-01-02 00:00:00        FLORENCIA                    175009
# ...                   ...              ...                       ...
# 1096  2017-03-13 00:00:00       WH - LERMA                    501692
# 1097  2017-03-27 00:00:00       WH - LERMA                    274132
# 1098  2017-05-03 00:00:00       WH - LERMA                    838390
# 1099  2017-05-22 00:00:00     CASA CLIENTE                    632364
# 1100  2017-05-25 00:00:00        FLORENCIA                    304039
#
#       IVA Precio de Compra  Precio de compra con IVA
# 0     IVA Precio de Compra  Precio de compra con IVA
# 1                        0                    114468
# 2                        0                    168102
# 3                        0                    174823
# 4                        0                    175009
# ...                    ...                       ...
# 1096                     0                    501692
# 1097                     0                    274132
# 1098                     0                    838390
# 1099                     0                    632364
# 1100                     0                    304039
#
# [1101 rows x 9 columns]

# %%
df2 = df2.iloc[1:]
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#        Stock ID & Marca Precio de Venta Con IVA # autos  Tipo de oferta  \
# 0              3453Seat                  131638       1       Inmediata
# 1        3452Volkswagen                  193317       1       Inmediata
# 2              3448Ford                  201046       1       Inmediata
# 3              3457Mini                  201261       1       Inmediata
# 4              3451Audi                  194123       1         30 días
# ...                 ...                     ...     ...             ...
# 1095  3899Mercedes Benz                  551861       1  A consignación
# 1096      4023Chevrolet                  301545       1  A consignación
# 1097      4320Chevrolet                  922229       1  A consignación
# 1098     4474Land Rover                  695600       1  A consignación
# 1099     4508Volkswagen                  334443       1  A consignación
#
#           Fecha de compra Location Compra Precio de compra SIN IVA  \
# 0     2017-01-02 00:00:00       FLORENCIA                   114468
# 1     2017-01-02 00:00:00       FLORENCIA                   168102
# 2     2017-01-02 00:00:00    CASA CLIENTE                   174823
# 3     2017-01-02 00:00:00       FLORENCIA                   175009
# 4     2017-01-02 00:00:00      WH - LERMA                   173324
# ...                   ...             ...                      ...
# 1095  2017-03-13 00:00:00      WH - LERMA                   501692
# 1096  2017-03-27 00:00:00      WH - LERMA                   274132
# 1097  2017-05-03 00:00:00      WH - LERMA                   838390
# 1098  2017-05-22 00:00:00    CASA CLIENTE                   632364
# 1099  2017-05-25 00:00:00       FLORENCIA                   304039
#
#      IVA Precio de Compra Precio de compra con IVA
# 0                       0                   114468
# 1                       0                   168102
# 2                       0                   174823
# 3                       0                   175009
# 4                       0                   173324
# ...                   ...                      ...
# 1095                    0                   501692
# 1096                    0                   274132
# 1097                    0                   838390
# 1098                    0                   632364
# 1099                    0                   304039
#
# [1100 rows x 9 columns]

# %%
df2[['Stock ID','Marca']] = df2['Stock ID & Marca'].str.split(n=2,expand=True)

# %%
df2.drop(['Stock ID','Marca'], axis=1,inplace=True)

# %%
df2
# Out:
#        Stock ID & Marca Precio de Venta Con IVA # autos  Tipo de oferta  \
# 0              3453Seat                  131638       1       Inmediata
# 1        3452Volkswagen                  193317       1       Inmediata
# 2              3448Ford                  201046       1       Inmediata
# 3              3457Mini                  201261       1       Inmediata
# 4              3451Audi                  194123       1         30 días
# ...                 ...                     ...     ...             ...
# 1095  3899Mercedes Benz                  551861       1  A consignación
# 1096      4023Chevrolet                  301545       1  A consignación
# 1097      4320Chevrolet                  922229       1  A consignación
# 1098     4474Land Rover                  695600       1  A consignación
# 1099     4508Volkswagen                  334443       1  A consignación
#
#           Fecha de compra Location Compra Precio de compra SIN IVA  \
# 0     2017-01-02 00:00:00       FLORENCIA                   114468
# 1     2017-01-02 00:00:00       FLORENCIA                   168102
# 2     2017-01-02 00:00:00    CASA CLIENTE                   174823
# 3     2017-01-02 00:00:00       FLORENCIA                   175009
# 4     2017-01-02 00:00:00      WH - LERMA                   173324
# ...                   ...             ...                      ...
# 1095  2017-03-13 00:00:00      WH - LERMA                   501692
# 1096  2017-03-27 00:00:00      WH - LERMA                   274132
# 1097  2017-05-03 00:00:00      WH - LERMA                   838390
# 1098  2017-05-22 00:00:00    CASA CLIENTE                   632364
# 1099  2017-05-25 00:00:00       FLORENCIA                   304039
#
#      IVA Precio de Compra Precio de compra con IVA
# 0                       0                   114468
# 1                       0                   168102
# 2                       0                   174823
# 3                       0                   175009
# 4                       0                   173324
# ...                   ...                      ...
# 1095                    0                   501692
# 1096                    0                   274132
# 1097                    0                   838390
# 1098                    0                   632364
# 1099                    0                   304039
#
# [1100 rows x 9 columns]

# %%
s = df2['Stock ID & Marca']
s = s.str.findall(r'[0-9]+')

# %%
df2['Stock ID'] = s

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Stock ID & Marca          1100 non-null   object
#  1   Precio de Venta Con IVA   1100 non-null   object
#  2   # autos                   1100 non-null   object
#  3   Tipo de oferta            1100 non-null   object
#  4   Fecha de compra           1100 non-null   object
#  5   Location Compra           1100 non-null   object
#  6   Precio de compra SIN IVA  1100 non-null   object
#  7   IVA Precio de Compra      1100 non-null   object
#  8   Precio de compra con IVA  1100 non-null   object
#  9   Stock ID                  1100 non-null   object
# dtypes: object(10)
# memory usage: 86.1+ KB

# %%
text = []
for i in s:
    text.append(i)

# %%
r = []
for i in text:
    for e in i:
        if e.isdigit():
            e.split()
            r.append(int(e))

# %%
df2['Stock ID'] = r

# %%
df2
# Out:
#        Stock ID & Marca Precio de Venta Con IVA # autos  Tipo de oferta  \
# 0              3453Seat                  131638       1       Inmediata
# 1        3452Volkswagen                  193317       1       Inmediata
# 2              3448Ford                  201046       1       Inmediata
# 3              3457Mini                  201261       1       Inmediata
# 4              3451Audi                  194123       1         30 días
# ...                 ...                     ...     ...             ...
# 1095  3899Mercedes Benz                  551861       1  A consignación
# 1096      4023Chevrolet                  301545       1  A consignación
# 1097      4320Chevrolet                  922229       1  A consignación
# 1098     4474Land Rover                  695600       1  A consignación
# 1099     4508Volkswagen                  334443       1  A consignación
#
#           Fecha de compra Location Compra Precio de compra SIN IVA  \
# 0     2017-01-02 00:00:00       FLORENCIA                   114468
# 1     2017-01-02 00:00:00       FLORENCIA                   168102
# 2     2017-01-02 00:00:00    CASA CLIENTE                   174823
# 3     2017-01-02 00:00:00       FLORENCIA                   175009
# 4     2017-01-02 00:00:00      WH - LERMA                   173324
# ...                   ...             ...                      ...
# 1095  2017-03-13 00:00:00      WH - LERMA                   501692
# 1096  2017-03-27 00:00:00      WH - LERMA                   274132
# 1097  2017-05-03 00:00:00      WH - LERMA                   838390
# 1098  2017-05-22 00:00:00    CASA CLIENTE                   632364
# 1099  2017-05-25 00:00:00       FLORENCIA                   304039
#
#      IVA Precio de Compra Precio de compra con IVA  Stock ID
# 0                       0                   114468      3453
# 1                       0                   168102      3452
# 2                       0                   174823      3448
# 3                       0                   175009      3457
# 4                       0                   173324      3451
# ...                   ...                      ...       ...
# 1095                    0                   501692      3899
# 1096                    0                   274132      4023
# 1097                    0                   838390      4320
# 1098                    0                   632364      4474
# 1099                    0                   304039      4508
#
# [1100 rows x 10 columns]

# %%
df3 = pd.read_excel(open('Prueba Tableau.xlsx', 'rb'),
              sheet_name='Initial Inventory',names=['Mes', 'Stock ID', 'Marca',
                                                       'Precio de Venta con IVA','# autos','Tipo de oferta',
                                                        'Fecha de Compra','Precio compra sin IVA',
                                                        'IVA','Precio total compra'])

# %%
df3 = df3.iloc[1:]
df3 = df3.reset_index(drop=True)

# %%
df3
# Out:
#                      Mes Stock ID       Marca Precio de Venta con IVA # autos  \
# 0    2018-12-31 00:00:00     1267  Volkswagen                  232299       1
# 1    2018-12-31 00:00:00     1535        Audi                  401244       1
# 2    2018-12-31 00:00:00     1559        Audi                  536804       1
# 3    2018-12-31 00:00:00     1638        Audi                  465571       1
# 4    2018-12-31 00:00:00     1689  Volkswagen                  369567       1
# ..                   ...      ...         ...                     ...     ...
# 480  2018-12-31 00:00:00     3216   Chevrolet                  552768       1
# 481  2018-12-31 00:00:00     3246   Chevrolet                  422064       1
# 482  2018-12-31 00:00:00     3264        Audi                  461287       1
# 483  2018-12-31 00:00:00     3436   Chevrolet                  191776       1
# 484  2018-12-31 00:00:00     3450        Jeep                  321723       1
#
#      Tipo de oferta      Fecha de Compra Precio compra sin IVA IVA  \
# 0         Inmediata  2016-09-01 00:00:00                205575   0
# 1         Inmediata  2016-12-04 00:00:00                355083   0
# 2         Inmediata  2016-12-08 00:00:00                475047   0
# 3         Inmediata  2016-12-29 00:00:00                412010   0
# 4         Inmediata  2016-01-15 00:00:00                327050   0
# ..              ...                  ...                   ...  ..
# 480  A consignación  2016-12-04 00:00:00                511823   0
# 481  A consignación  2016-12-07 00:00:00                390800   0
# 482  A consignación  2016-12-10 00:00:00                427117   0
# 483  A consignación  2016-12-29 00:00:00                177570   0
# 484  A consignación  2016-12-24 00:00:00                297892   0
#
#     Precio total compra
# 0                205575
# 1                355083
# 2                475047
# 3                412010
# 4                327050
# ..                  ...
# 480              511823
# 481              390800
# 482              427117
# 483              177570
# 484              297892
#
# [485 rows x 10 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Mes                      485 non-null    object
#  1   Stock ID                 485 non-null    object
#  2   Marca                    485 non-null    object
#  3   Precio de Venta con IVA  485 non-null    object
#  4   # autos                  485 non-null    object
#  5   Tipo de oferta           485 non-null    object
#  6   Fecha de Compra          485 non-null    object
#  7   Precio compra sin IVA    485 non-null    object
#  8   IVA                      485 non-null    object
#  9   Precio total compra      485 non-null    object
# dtypes: object(10)
# memory usage: 38.0+ KB

# %%
writer = pd.ExcelWriter('Prueba Tableau limpia.xlsx', engine='xlsxwriter')


df.to_excel(writer, sheet_name='Monthly Sales',index = False)
df2.to_excel(writer, sheet_name='Purchases',index = False)
df3.to_excel(writer, sheet_name='Initial Inventory', index = False)

writer.save()
